# %%
# Question 2
def find_GC_content(seq):

  GC = 0
  for nt in seq:
    if nt in ("G","C"):
      GC+=1

  GCp = (GC/len(seq))*100
  return(GCp, GC)

seq = "..."
output = find_GC_content(seq)
print("The GC content is:", output[0])
print("The number of GC nucleotides is:", output[1])
print("The total number of nucleotides is:", len(seq))
# Out:
# The GC content is: 46.52777777777778
# The number of GC nucleotides is: 201
# The total number of nucleotides is: 432
