# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pprint
import re

# %%
# Question 2
fasta_file = "/content/drive/MyDrive/BT3040-Assignments/Lab Assignment - 3/uniref_transcription_factors_fasta_file.fasta"
with open(fasta_file_path, "r") as f:
    lines = f.readlines()

# %%
seq_count = 0
cluster_count = 0
for line in lines:
  if line[0] == ">":
    match = re.search(r"n=(\d+)", line)
    number = int(match.group(1))
    seq_count+=number
    cluster_count+=1

print("The number of sequences:", seq_count)
print("The number of clusters:", cluster_count)
# Out:
# The number of sequences: 2748
# The number of clusters: 205
